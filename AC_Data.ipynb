# %%
# Import Dependencies
import pandas as pd
from sqlalchemy import create_engine
import datetime

# %%
# Dictionary for all the apparels 
df_recipes = pd.read_csv("AC_Resources/recipes.csv")
df_tops = pd.read_csv("AC_Resources/tops.csv")
df_bottoms = pd.read_csv("AC_Resources/bottoms.csv")
df_dressup = pd.read_csv("AC_Resources/dress-up.csv")
df_headwear = pd.read_csv("AC_Resources/headwear.csv")
df_accessories = pd.read_csv("AC_Resources/accessories.csv")
df_socks = pd.read_csv("AC_Resources/socks.csv")
df_shoes = pd.read_csv("AC_Resources/shoes.csv")
df_bags = pd.read_csv("AC_Resources/bags.csv")
df_unbrellas = pd.read_csv("AC_Resources/umbrellas.csv")

# %%
# # Dictionary for all the Fish, Incects, Fossils and Arts
# df_fish = pd.read_csv("AC_Resources/fish.csv")
# df_fossils = pd.read_csv("AC_Resources/fossils.csv")
# df_insects = pd.read_csv("AC_Resources/insects.csv")
# df_art = pd.read_csv("AC_Resources/art.csv")

# %%
# Name, Materials, Buy, Sell , Miles Price, Source Category, Internal ID
df_recipes.head()
# Out:
#               Name  #1 Material 1   #2   Material 2  #3 Material 3  #4  \
# 0   acorn pochette   6      acorn  NaN          NaN NaN        NaN NaN
# 1  acoustic guitar   8   softwood  3.0  iron nugget NaN        NaN NaN
# 2  angled signpost   2   hardwood  3.0     softwood NaN        NaN NaN
# 3      apple chair  10      apple  4.0         wood NaN        NaN NaN
# 4      apple dress   8      apple  NaN          NaN NaN        NaN NaN
#
#   Material 4  #5  ... Sell  Miles Price                Source  \
# 0        NaN NaN  ...  200          NaN              Balloons
# 1        NaN NaN  ...  200          NaN        Smug villagers
# 2        NaN NaN  ...  200          NaN        Lazy villagers
# 3        NaN NaN  ...  200          NaN  Big Sister villagers
# 4        NaN NaN  ...  200          NaN  Big Sister villagers
#
#                  Source Notes  Recipes to Unlock  Version    Category  \
# 0  Only available during Fall                  0    1.0.0        Bags
# ...

# %%
# name, DIY, Buy, Sell, Miles price,Source, Internal ID
df_tops.head()
df_cols = ['Name','DIY','Buy','Sell','Source','Seasonal Availability','Internal ID']
df_tops.head()
# Out:
#                   Name  Variation DIY   Buy  Sell Color 1 Color 2 Size  \
# 0                A tee        NaN  No   560   140    Blue   White  1x1
# 1   acid-washed jacket       Blue  No  1680   420    Blue    Blue  1x1
# 2   acid-washed jacket      Black  No  1680   420   Black   Black  1x1
# 3  after-school jacket      Black  No  1050   262   Black     Red  1x1
# 4  after-school jacket  Berry red  No  1050   262     Red   Green  1x1
#
#    Miles Price                 Source  ... Seasonal Availability  \
# 0          NaN  Nook Shopping Catalog  ...              All Year
# 1          NaN           Able Sisters  ...              All Year
# 2          NaN           Able Sisters  ...              All Year
# 3          NaN           Able Sisters  ...              All Year
# 4          NaN           Able Sisters  ...              All Year
#
#   Mannequin Piece Version   Style         Label Themes Villager Equippable  \
# ...

# %%
df_bottoms[df_cols]
# Out:
#                      Name DIY   Buy  Sell        Source Seasonal Availability  \
# 0       acid-washed jeans  No  1320   330  Able Sisters              All Year
# 1       acid-washed jeans  No  1320   330  Able Sisters              All Year
# 2    animal-stripes skirt  No  1100   275  Able Sisters              All Year
# 3    animal-stripes skirt  No  1100   275  Able Sisters              All Year
# 4             apron skirt  No   700   175  Able Sisters              All Year
# ..                    ...  ..   ...   ...           ...                   ...
# 721        worn-out jeans  No  1100   275  Able Sisters              All Year
# 722          yacht shorts  No   840   210  Able Sisters                Summer
# 723          yacht shorts  No   840   210  Able Sisters                Summer
# 724          yacht shorts  No   840   210  Able Sisters                Summer
# 725          yacht shorts  No   840   210  Able Sisters                Summer
#
#      Internal ID
# ...

# %%
df_dressup[df_cols]
# Out:
#                    Name DIY   Buy  Sell        Source Seasonal Availability  \
# 0       academy uniform  No  2080   520  Able Sisters              All Year
# 1       academy uniform  No  2080   520  Able Sisters              All Year
# 2       academy uniform  No  2080   520  Able Sisters              All Year
# 3       adventure dress  No  2800   700  Able Sisters              All Year
# 4        alpinist dress  No  2520   630  Able Sisters              All Year
# ..                  ...  ..   ...   ...           ...                   ...
# 908  zigzag-print dress  No  2000   500  Able Sisters                Summer
# 909  zigzag-print dress  No  2000   500  Able Sisters                Summer
# 910  zigzag-print dress  No  2000   500  Able Sisters                Summer
# 911  zigzag-print dress  No  2000   500  Able Sisters                Summer
# 912  zigzag-print dress  No  2000   500  Able Sisters                Summer
#
#      Internal ID
# 0           2699
# 1           9016
# ...

# %%
df_accessories[df_cols]
# Out:
#                      Name DIY   Buy  Sell        Source Seasonal Availability  \
# 0              3D glasses  No   490   122  Able Sisters              All Year
# 1              3D glasses  No   490   122  Able Sisters              All Year
# 2                 bandage  No   140    35  Able Sisters              All Year
# 3                    beak  No   490   122  Able Sisters              All Year
# 4         birthday shades  No   NFS   620      Birthday              All Year
# ..                    ...  ..   ...   ...           ...                   ...
# 217       triangle shades  No   880   220  Able Sisters              All Year
# 218       triangle shades  No   880   220  Able Sisters              All Year
# 219       triangle shades  No   880   220  Able Sisters              All Year
# 220  wooden-frame glasses  No  1560   390  Able Sisters              All Year
# 221  wooden-frame glasses  No  1560   390  Able Sisters              All Year
#
#      Internal ID
# ...

# %%
df_bags[df_cols]
# Out:
#                    Name  DIY   Buy  Sell    Source Seasonal Availability  \
# 0        acorn pochette  Yes   NFS  2400  Crafting              All Year
# 1           basket pack  Yes   NFS  2400  Crafting              All Year
# 2              bug cage   No   NFS   122   Bug-Off              All Year
# 3         Bunny Day bag  Yes   NFS  2400  Crafting              All Year
# 4    butterfly backpack   No   NFS   210   Bug-Off              All Year
# ..                  ...  ...   ...   ...       ...                   ...
# 91         travel pouch   No   840   210     Kicks              All Year
# 92         travel pouch   No   840   210     Kicks              All Year
# 93  traveler's backpack   No  2940   735     Kicks              All Year
# 94  traveler's backpack   No  2940   735     Kicks              All Year
# 95  traveler's backpack   No  2940   735     Kicks              All Year
#
#     Internal ID
# 0          7492
# 1          7506
# 2          7479
# 3         12447
# ...

# %%
df_headwear[df_cols]
# Out:
#                Name DIY   Buy  Sell        Source Seasonal Availability  \
# 0    acorn knit cap  No   880   220  Able Sisters              All Year
# 1    acorn knit cap  No   880   220  Able Sisters              All Year
# 2    acorn knit cap  No   880   220  Able Sisters              All Year
# 3    acorn knit cap  No   880   220  Able Sisters              All Year
# 4    acorn knit cap  No   880   220  Able Sisters              All Year
# ..              ...  ..   ...   ...           ...                   ...
# 693   zen hair clip  No  4300  1075  Able Sisters              All Year
# 694   zen hair clip  No  4300  1075  Able Sisters              All Year
# 695   zen hair clip  No  4300  1075  Able Sisters              All Year
# 696   zen hair clip  No  4300  1075  Able Sisters              All Year
# 697   zen hair clip  No  4300  1075  Able Sisters              All Year
#
#      Internal ID
# 0           5315
# 1          10933
# 2          10934
# 3          10935
# ...

# %%
df_shoes[df_cols]
# Out:
#               Name  DIY   Buy  Sell        Source Seasonal Availability  \
# 0    antique boots   No  2640   660  Able Sisters              All Year
# 1    antique boots   No  2640   660  Able Sisters              All Year
# 2    antique boots   No  2640   660  Able Sisters              All Year
# 3      armor shoes  Yes   NFS  3000      Crafting              All Year
# 4        babouches   No   560   140         Kicks              All Year
# ..             ...  ...   ...   ...           ...                   ...
# 449           zori   No  4300  1075  Able Sisters              All Year
# 450           zori   No  4300  1075  Able Sisters              All Year
# 451           zori   No  4300  1075  Able Sisters              All Year
# 452           zori   No  4300  1075  Able Sisters              All Year
# 453           zori   No  4300  1075  Able Sisters              All Year
#
#      Internal ID
# 0           5523
# 1          11689
# 2          11690
# 3           5472
# ...

# %%
df_socks[df_cols]
# Out:
#                   Name DIY  Buy  Sell Source Seasonal Availability  \
# 0    aerobics leggings  No  700   175  Kicks              All Year
# 1    aerobics leggings  No  700   175  Kicks              All Year
# 2    aerobics leggings  No  700   175  Kicks              All Year
# 3    aerobics leggings  No  700   175  Kicks              All Year
# 4    aerobics leggings  No  700   175  Kicks              All Year
# ..                 ...  ..  ...   ...    ...                   ...
# 345   wave-print socks  No  600   150  Kicks              All Year
# 346   wave-print socks  No  600   150  Kicks              All Year
# 347   wave-print socks  No  600   150  Kicks              All Year
# 348   wave-print socks  No  600   150  Kicks              All Year
# 349   wave-print socks  No  600   150  Kicks              All Year
#
#      Internal ID
# 0           5197
# 1           9794
# 2           9795
# 3           9796
# 4           9797
# ..           ...
# 345         5813
# ...

# %%
df_unbrellas[df_cols]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-1aa41ee15b63> in <module>
# ----> 1 df_unbrellas[df_cols]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550
#    1551         self._validate_read_indexer(
# -> 1552             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1553         )
#    1554         return keyarr, indexer
#
# ...
