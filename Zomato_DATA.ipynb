# %%
# Import dependencies needed

import json
import pandas as pd
from pprint import pprint

# %%
# Load file1.json' file into dataframe:

file1 = pd.read_json('Resources/file1.json', lines=True, orient='columns')
file1.head()
# Out:
#                                                  0    \
# 0  {'results_found': 17151, 'restaurants': [{'res...
#
#                                                  1    \
# 0  {'results_found': 4748, 'restaurants': [{'rest...
#
#                                                  2    \
# 0  {'results_found': 13786, 'restaurants': [{'res...
#
#                                                  3    \
# 0  {'results_found': 10224, 'restaurants': [{'res...
#
#                                                  4    \
# 0  {'results_found': 7039, 'restaurants': [{'rest...
#
#                                                  5    \
# 0  {'results_found': 5678, 'restaurants': [{'rest...
#
#                                                  6    \
# 0  {'results_found': 5374, 'restaurants': [{'rest...
#
#                                                  7    \
# 0  {'results_found': 1382, 'restaurants': [{'rest...
#
#                                                  8    \
# ...
